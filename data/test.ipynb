# %%
from fetcher import *
from finmind import *

# %% [markdown]
# ### fetcher

# %%
fetch_twse_daily(20260323)
# Out:
# []

# %%
fetch_twse_stock(2330,'2025-01-01','2026-03-23')
# Out:
# [{'symbol': 2330,
#   'date': '2025-01-02',
#   'open': 1070.0,
#   'high': 1075.0,
#   'low': 1055.0,
#   'close': 1065.0,
#   'volume': 45045125},
#  {'symbol': 2330,
#   'date': '2025-01-03',
#   'open': 1080.0,
#   'high': 1085.0,
#   'low': 1075.0,
#   'close': 1075.0,
#   'volume': 31244211},
#  {'symbol': 2330,
#   'date': '2025-01-06',
#   'open': 1100.0,
#   'high': 1125.0,
#   'low': 1095.0,
#   'close': 1125.0,
#   'volume': 77874801},
#  {'symbol': 2330,
#   'date': '2025-01-07',
#   'open': 1150.0,
#   'high': 1160.0,
#   'low': 1130.0,
#   'close': 1130.0,
#   'volume': 54691485},
#  {'symbol': 2330,
#   'date': '2025-01-08',
#   'open': 1110.0,
#   'high': 1130.0,
#   'low': 1105.0,
#   'close': 1105.0,
#   'volume': 49181518},
#  {'symbol': 2330,
#   'date': '2025-01-09',
#   'open': 1100.0,
#   'high': 1115.0,
#   'low': 1100.0,
#   'close': 1100.0,
#   'volume': 29916198},
#  {'symbol': 2330,
#   'date': '2025-01-10',
#   'open': 1100.0,
#   'high': 1110.0,
# ...

# %%
fetch_tpex_otc_stock(6510, '2025-01-01', '2026-03-23')
# Out:
#   [TPEx OTC] 6510 114/01/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx OTC] 6510 114/02/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx OTC] 6510 114/03/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx OTC] 6510 114/04/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx OTC] 6510 114/05/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx OTC] 6510 114/06/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx OTC] 6510 114/07/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx OTC] 6510 114/08/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx OTC] 6510 114/09/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx OTC] 6510 114/10/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx OTC] 6510 114/11/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx OTC] 6510 114/12/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx OTC] 6510 115/01/01 失敗: Expecting value: line 1 column 1 (char 0)
# ...

# %%
 fetch_tpex_emerging(7815, '2025-01-01', '2026-03-23')
# Out:
#   [TPEx Emerging] 7815 114/01/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx Emerging] 7815 114/02/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx Emerging] 7815 114/03/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx Emerging] 7815 114/04/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx Emerging] 7815 114/05/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx Emerging] 7815 114/06/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx Emerging] 7815 114/07/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx Emerging] 7815 114/08/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx Emerging] 7815 114/09/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx Emerging] 7815 114/10/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx Emerging] 7815 114/11/01 失敗: Expecting value: line 1 column 1 (char 0)
#   [TPEx Emerging] 7815 114/12/01 失敗: Expecting value: line 1 column 1 (char 0)
# ...

# %%
fetch_taifex_futures('TX', '2025/01/01', '2026/03/23')
# Out:
# [{'symbol': 'TX_TX',
#   'date': '2025-01-03',
#   'open': 22935.0,
#   'high': 23108.0,
#   'low': 22905.0,
#   'close': 22977.0,
#   'volume': 134},
#  {'symbol': 'TX_TX',
#   'date': '2025-01-03',
#   'open': 22853.0,
#   'high': 22997.0,
#   'low': 22731.0,
#   'close': 22847.0,
#   'volume': 4},
#  {'symbol': 'TX_TX',
#   'date': '2025-01-03',
#   'open': 22980.0,
#   'high': 23161.0,
#   'low': 22976.0,
#   'close': 23045.0,
#   'volume': 135},
#  {'symbol': 'TX_TX',
#   'date': '2025-01-03',
#   'open': 22904.0,
#   'high': 23060.0,
#   'low': 22800.0,
#   'close': 22918.0,
#   'volume': 8},
#  {'symbol': 'TX_TX',
#   'date': '2025-01-03',
#   'open': 23080.0,
#   'high': 23180.0,
#   'low': 23025.0,
#   'close': 23051.0,
#   'volume': 101},
#  {'symbol': 'TX_TX',
#   'date': '2025-01-03',
#   'open': 23253.0,
#   'high': 23289.0,
#   'low': 23150.0,
#   'close': 23250.0,
#   'volume': 193},
#  {'symbol': 'TX_TX',
#   'date': '2025-01-03',
#   'open': 23012.0,
# ...

# %%
fetch_yfinance('avgo', period='1y')
# Out:
# [{'symbol': 'avgo',
#   'date': '2025-03-24',
#   'open': np.float64(193.14),
#   'high': np.float64(195.52),
#   'low': np.float64(189.53),
#   'close': np.float64(190.11),
#   'volume': 33180300},
#  {'symbol': 'avgo',
#   'date': '2025-03-25',
#   'open': np.float64(189.75),
#   'high': np.float64(190.46),
#   'low': np.float64(186.56),
#   'close': np.float64(187.14),
#   'volume': 23417300},
#  {'symbol': 'avgo',
#   'date': '2025-03-26',
#   'open': np.float64(185.55),
#   'high': np.float64(186.94),
#   'low': np.float64(176.52),
#   'close': np.float64(178.2),
#   'volume': 30578500},
#  {'symbol': 'avgo',
#   'date': '2025-03-27',
#   'open': np.float64(176.6),
#   'high': np.float64(177.32),
#   'low': np.float64(169.44),
#   'close': np.float64(170.97),
#   'volume': 32151700},
#  {'symbol': 'avgo',
#   'date': '2025-03-28',
#   'open': np.float64(170.91),
#   'high': np.float64(172.27),
#   'low': np.float64(165.48),
#   'close': np.float64(168.11),
# ...

# %% [markdown]
# ### finmind

# %%
fetch_institutional(2330, '2025-01-01', end_date=None)
# Out:
# 📥 [FinMind] 法人買賣超 2330 (2025-01-01 ~ 2026-03-24)
#   ✅ 0 筆
# 0

# %%
fetch_margin(2330, '2025-01-01', end_date=None)
# Out:
# 📥 [FinMind] 融資融券 2330 (2025-01-01 ~ 2026-03-24)
#   ✅ 0 筆
# 0

# %%
fetch_revenue(2330, '2025-01-01', end_date=None)
# Out:
# 📥 [FinMind] 月營收 2330 (2025-01-01 ~ 2026-03-24)
#   ✅ 0 筆
# 0

# %%
fetch_per(2330, '2025-01-01', end_date=None)
# Out:
# 📥 [FinMind] PER/PBR 2330 (2025-01-01 ~ 2026-03-24)
#   ✅ 0 筆
# 0

# %%
batch_download(2330, start_date='2024-01-01')
# Out:
# === 批次下載 2330 籌碼資料 ===
# 📥 [FinMind] 法人買賣超 2330 (2024-01-01 ~ 2026-03-24)
#   ✅ 0 筆
# 📥 [FinMind] 融資融券 2330 (2024-01-01 ~ 2026-03-24)
#   ✅ 0 筆
# 📥 [FinMind] 月營收 2330 (2024-01-01 ~ 2026-03-24)
#   ✅ 0 筆
# 📥 [FinMind] PER/PBR 2330 (2024-01-01 ~ 2026-03-24)
#   ✅ 0 筆
# === 2330 完成 ===
